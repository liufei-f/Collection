# %% [markdown]
# Pleiotropy:
#
# A condition in which a single gene or genetic variant influences multiple phenotypic traits

# %% [markdown]
# Dominance:
#
# The phenomenon of one variant (allele) of a gene on a chromosome masking or overriding the effect of a different variant of the same gene on the other copy of the chromosome. The first variant is termed dominant and the second is called recessive.

# %% [markdown]
# Epistasis:
#
# A phenomenon in genetics in which the effect of a gene mutation is dependent on the presence or absence of mutations in one or more other genes, respectively termed modifier genes.
# In other words, the effect of the mutation is dependent on the genetic background in which it appears.
